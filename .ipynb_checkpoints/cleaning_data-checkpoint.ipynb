# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our mental health dataset and create a dataframe
mental_df = pd.read_csv('./Resources/mental-heath-in-tech-2016_20161114.csv')
mental_df.head()
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
# 2                                               6-25
# 3                                                NaN
# 4                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# ...

# %%
mental_df.shape
# Out:
# (1433, 63)

# %%
high_response_df = mental_df

# %%
# Check response rate and drop columns
low_responses = []
for column in high_response_df.columns:
    if ((high_response_df[column].count() / 1433) < .7):
        
        
high_response_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-1b937df4cdb6> in <module>
#       2 for column in high_response_df.columns:
#       3     if ((high_response_df[column].count() / 1433) < .7):
# ----> 4         high_response_df = high_response_df.drop([column], inplace=False)
#       5
#       6 high_response_df
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
for column in mental_df.columns:
    print()
    print('Column #: ' + str(count))
    print()
    print(mental_df[column].value_counts())
    print()
    print('Number of unique values: ' + str(mental_df[column].nunique()))
    print('% complete: ' + str(mental_df[column].count() / 1433 * 100))
    print('------------------------')
    count = count + 1

# %% [markdown]
# 4. Is your primary role within your company related to tech/IT? - drop due to low response rate.
# 17. Do you have medical coverage (private insurance or state-provided) which includes treatment of  mental health issues? - drop due to low response rate
# 18. Do you know local or online resources to seek help for a mental health disorder? - drop due to low response rate
# 19. If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts? - drop due to low response rate
# 20. If you have revealed a mental health issue to a client or business contact, do you believe this has impacted you negatively? - drop due to low response rate
# 21. If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees? - drop due to low response rate
# 22. If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively? - drop due to low response rate
# 23. Do you believe your productivity is ever affected by a mental health issue? - drop due to low response rate
# 24. If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue? - drop due to low response rate
