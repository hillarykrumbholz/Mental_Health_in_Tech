# %%
# Import dependencies 
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sqlalchemy import create_engine

# %%
# Load data from Resources as tab seperated file into dataframe
pd.set_option('display.max_columns', None)
mental_df = pd.read_csv('./Resources/cleaned_data.csv')
mental_df
# Out:
#     Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                                                   No
# 1                                                  Yes
# 2                                                  Yes
# 3                                         I don't know
# 4                                                  Yes
# ..                                                 ...
# 856                                                Yes
# 857                                       I don't know
# 858                                                Yes
# 859                                                Yes
# 860                                       I don't know
#
#     Do you know the options for mental health care available under your employer-provided coverage?  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                        I am not sure
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 856                                      I am not sure
# 857                                      I am not sure
# 858                                                 No
# 859                                                Yes
# 860                                      I am not sure
#
#     Does your employer offer resources to learn more about mental health concerns and options for seeking help?  \
# 0                                                  Yes
# 1                                                   No
# 2                                                  Yes
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 856                                                Yes
# 857                                       I don't know
# 858                                                 No
# 859                                                Yes
# 860                                                Yes
#
#     If a mental health issue prompted you to request a medical leave from work asking for that leave would be:  \
# 0                                        Somewhat easy
# 1                           Neither easy nor difficult
# 2                                        Somewhat easy
# 3                                        Somewhat easy
# 4                                            Very easy
# ..                                                 ...
# 856                                      Somewhat easy
# 857                                      Somewhat easy
# 858                                      Somewhat easy
# 859                                 Somewhat difficult
# 860                                 Somewhat difficult
#
#     Do you think that discussing a mental health disorder with your employer would have negative consequences?  \
# 0                                                   No
# 1                                                  Yes
# 2                                                  Yes
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 856                                                 No
# 857                                              Maybe
# 858                                                 No
# 859                                              Maybe
# 860                                              Maybe
#
#     Do you think that discussing a physical health issue with your employer would have negative consequences?  \
# 0                                                   No
# 1                                                Maybe
# 2                                                  Yes
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 856                                                 No
# 857                                                 No
# 858                                                 No
# 859                                              Maybe
# 860                                                 No
#
#     Do you feel that your employer takes mental health as seriously as physical health?  \
# 0                                                  Yes
# 1                                                   No
# 2                                                   No
# 3                                                  Yes
# 4                                         I don't know
# ..                                                 ...
# 856                                                Yes
# 857                                       I don't know
# 858                                                Yes
# 859                                       I don't know
# 860                                                 No
#
#     Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?  \
# 0                                                   No
# 1                                                   No
# 2                                                  Yes
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 856                                                 No
# 857                                                 No
# 858                                                 No
# 859                                                Yes
# 860                                                 No
#
#      Do you have previous employers?  \
# 0                                  1
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  1
# ..                               ...
# 856                                1
# 857                                1
# 858                                1
# 859                                1
# 860                                1
#
#     Have your previous employers provided mental health benefits?  \
# 0                                     Yes they all did
# 1                                         I don't know
# 2                                          No none did
# 3                                             Some did
# 4                                             Some did
# ..                                                 ...
# 856                                           Some did
# 857                                       I don't know
# 858                                           Some did
# 859                                           Some did
# 860                                        No none did
#
#     Were you aware of the options for mental health care provided by your previous employers?  \
# 0                                  I was aware of some
# 1                            N/A (not currently aware)
# 2                       Yes I was aware of all of them
# 3                                  I was aware of some
# 4                                  I was aware of some
# ..                                                 ...
# 856                       No I only became aware later
# 857                          N/A (not currently aware)
# 858                                I was aware of some
# 859                                I was aware of some
# 860                          N/A (not currently aware)
#
#     Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?  \
# 0                                             None did
# 1                                             Some did
# 2                                             None did
# 3                                             None did
# 4                                             Some did
# ..                                                 ...
# 856                                           Some did
# 857                                       I don't know
# 858                                           None did
# 859                                           None did
# 860                                           None did
#
#     Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?  \
# 0                                           Yes always
# 1                                         I don't know
# 2                                         I don't know
# 3                                         I don't know
# 4                                            Sometimes
# ..                                                 ...
# 856                                         Yes always
# 857                                       I don't know
# 858                                       I don't know
# 859                                          Sometimes
# 860                                       I don't know
#
#     Do you think that discussing a mental health disorder with previous employers would have negative consequences?  \
# 0                                         None of them
# 1                                         Some of them
# 2                                      Yes all of them
# 3                                         None of them
# 4                                         Some of them
# ..                                                 ...
# 856                                       Some of them
# 857                                       Some of them
# 858                                       Some of them
# 859                                    Yes all of them
# 860                                    Yes all of them
#
#     Would you have been willing to discuss a mental health issue with your direct supervisor(s)?  \
# 0                        Some of my previous employers
# 1                        Some of my previous employers
# 2                  No at none of my previous employers
# 3                  Yes at all of my previous employers
# 4                        Some of my previous employers
# ..                                                 ...
# 856                No at none of my previous employers
# 857                      Some of my previous employers
# 858                No at none of my previous employers
# 859                      Some of my previous employers
# 860                No at none of my previous employers
#
#     Did you feel that your previous employers took mental health as seriously as physical health?  \
# 0                                             Some did
# 1                                             Some did
# 2                                             None did
# 3                                             Some did
# 4                                             Some did
# ..                                                 ...
# 856                                           Some did
# 857                                           Some did
# 858                                           None did
# 859                                           None did
# 860                                           None did
#
#     Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?  \
# 0                                         None of them
# 1                                         Some of them
# 2                                         Some of them
# 3                                         None of them
# 4                                         Some of them
# ..                                                 ...
# 856                                       None of them
# 857                                       None of them
# 858                                    Yes all of them
# 859                                       Some of them
# 860                                       None of them
#
#     Would you bring up a mental health issue with a potential employer in an interview?  \
# 0                                                   No
# 1                                                   No
# 2                                                Maybe
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 856                                                 No
# 857                                              Maybe
# 858                                                 No
# 859                                                 No
# 860                                                 No
#
#     Do you feel that being identified as a person with a mental health issue would hurt your career?  \
# 0                            No I don't think it would
# 1                                 Yes I think it would
# 2                                 Yes I think it would
# 3                                 Yes I think it would
# 4                                                Maybe
# ..                                                 ...
# 856                               Yes I think it would
# 857                                         Yes it has
# 858                                              Maybe
# 859                                         Yes it has
# 860                          No I don't think it would
#
#     Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?  \
# 0                          No I don't think they would
# 1                                                Maybe
# 2                                                Maybe
# 3                          No I don't think they would
# 4                                                Maybe
# ..                                                 ...
# 856                                              Maybe
# 857                                              Maybe
# 858                        No I don't think they would
# 859                        No I don't think they would
# 860                        No I don't think they would
#
#     How willing would you be to share with friends and family that you have a mental illness?  \
# 0                                        Somewhat open
# 1                                        Somewhat open
# 2                                        Somewhat open
# 3    Not applicable to me (I do not have a mental i...
# 4                                        Somewhat open
# ..                                                 ...
# 856                                  Somewhat not open
# 857                                      Somewhat open
# 858                                          Very open
# 859                                      Somewhat open
# 860                                      Somewhat open
#
#     Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?  \
# 0                                                   No
# 1                                    Yes I experienced
# 2                                    Yes I experienced
# 3                                                   No
# 4                                       Yes I observed
# ..                                                 ...
# 856                                                 No
# 857                                  Yes I experienced
# 858                                  Yes I experienced
# 859                                     Yes I observed
# 860                                  Yes I experienced
#
#     Do you have a family history of mental illness?  \
# 0                                               Yes
# 1                                               Yes
# 2                                                No
# 3                                                No
# 4                                               Yes
# ..                                              ...
# 856                                    I don't know
# 857                                    I don't know
# 858                                             Yes
# 859                                             Yes
# 860                                             Yes
#
#     Have you had a mental health disorder in the past?  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                   No
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 856                                              Maybe
# 857                                                Yes
# 858                                                Yes
# 859                                                Yes
# 860                                              Maybe
#
#     Do you currently have a mental health disorder?  \
# 0                                               Yes
# 1                                               Yes
# 2                                               Yes
# 3                                                No
# 4                                               Yes
# ..                                              ...
# 856                                           Maybe
# 857                                             Yes
# 858                                             Yes
# 859                                           Maybe
# 860                                             Yes
#
#     Have you been diagnosed with a mental health condition by a medical professional?  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                   No
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 856                                                 No
# 857                                                Yes
# 858                                                Yes
# 859                                                Yes
# 860                                                Yes
#
#      Have you ever sought treatment for a mental health issue from a mental health professional?  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    0
# 4                                                    1
# ..                                                 ...
# 856                                                  0
# 857                                                  1
# 858                                                  1
# 859                                                  1
# 860                                                  0
#
#     If you have a mental health issue do you feel that it interferes with your work when being treated effectively?  \
# 0                                               Rarely
# 1                                            Sometimes
# 2                                 Not applicable to me
# 3                                 Not applicable to me
# 4                                            Sometimes
# ..                                                 ...
# 856                                             Rarely
# 857                                             Rarely
# 858                                             Rarely
# 859                                             Rarely
# 860                                          Sometimes
#
#     If you have a mental health issue do you feel that it interferes with your work when NOT being treated effectively?  \
# 0                                            Sometimes
# 1                                            Sometimes
# 2                                                Often
# 3                                 Not applicable to me
# 4                                                Often
# ..                                                 ...
# 856                                             Rarely
# 857                                              Often
# 858                                              Often
# 859                                          Sometimes
# 860                                              Often
#
#     What is your gender? What country do you live in?  \
# 0                   Male     United States of America
# 1                 Female     United States of America
# 2                   Male               United Kingdom
# 3                   Male     United States of America
# 4                 Female     United States of America
# ..                   ...                          ...
# 856                 Male                       Canada
# 857               Female                       Canada
# 858               Female     United States of America
# 859                 Male     United States of America
# 860               Female     United States of America
#
#     What country do you work in?
# 0       United States of America
# 1       United States of America
# 2                 United Kingdom
# 3       United States of America
# 4       United States of America
# ..                           ...
# 856                       Canada
# 857                       Canada
# 858     United States of America
# 859     United States of America
# 860     United States of America
#
# [861 rows x 32 columns]

# %% [markdown]
# # Creating tables with categorical variables for database

# %%
# build a dataframe of the questions
dict = {}
count = 0
for column in mental_df.columns:
    
    dict[count] = [column]
    count = count + 1
    
    
dict

questions_df = pd.DataFrame.from_dict(dict, orient='index', columns=['Question'])
questions_df
# Out:
#                                              Question
# 0   Does your employer provide mental health benef...
# 1   Do you know the options for mental health care...
# 2   Does your employer offer resources to learn mo...
# 3   If a mental health issue prompted you to reque...
# 4   Do you think that discussing a mental health d...
# 5   Do you think that discussing a physical health...
# 6   Do you feel that your employer takes mental he...
# 7   Have you heard of or observed negative consequ...
# 8                     Do you have previous employers?
# 9   Have your previous employers provided mental h...
# 10  Were you aware of the options for mental healt...
# 11  Did your previous employers ever formally disc...
# 12  Was your anonymity protected if you chose to t...
# 13  Do you think that discussing a mental health d...
# 14  Would you have been willing to discuss a menta...
# 15  Did you feel that your previous employers took...
# 16  Did you hear of or observe negative consequenc...
# 17  Would you bring up a mental health issue with ...
# 18  Do you feel that being identified as a person ...
# 19  Do you think that team members/co-workers woul...
# 20  How willing would you be to share with friends...
# 21  Have you observed or experienced an unsupporti...
# 22    Do you have a family history of mental illness?
# 23  Have you had a mental health disorder in the p...
# 24    Do you currently have a mental health disorder?
# 25  Have you been diagnosed with a mental health c...
# 26  Have you ever sought treatment for a mental he...
# 27  If you have a mental health issue do you feel ...
# 28  If you have a mental health issue do you feel ...
# 29                               What is your gender?
# 30                       What country do you live in?
# 31                       What country do you work in?

# %%
# rename the columns in the dataframe to numbers
column_rename = {}
count = 0
for column in mental_df.columns:
    
    column_rename[column] = count
    count = count + 1
    
    
column_rename

renamed_df = mental_df.rename(columns=column_rename)
renamed_df
# Out:
#                0              1             2                           3   \
# 0              No            Yes           Yes               Somewhat easy
# 1             Yes            Yes            No  Neither easy nor difficult
# 2             Yes  I am not sure           Yes               Somewhat easy
# 3    I don't know             No            No               Somewhat easy
# 4             Yes            Yes           Yes                   Very easy
# ..            ...            ...           ...                         ...
# 856           Yes  I am not sure           Yes               Somewhat easy
# 857  I don't know  I am not sure  I don't know               Somewhat easy
# 858           Yes             No            No               Somewhat easy
# 859           Yes            Yes           Yes          Somewhat difficult
# 860  I don't know  I am not sure           Yes          Somewhat difficult
#
#         4      5             6    7   8                 9   \
# 0       No     No           Yes   No   1  Yes they all did
# 1      Yes  Maybe            No   No   1      I don't know
# 2      Yes    Yes            No  Yes   1       No none did
# 3       No     No           Yes   No   1          Some did
# 4       No     No  I don't know   No   1          Some did
# ..     ...    ...           ...  ...  ..               ...
# 856     No     No           Yes   No   1          Some did
# 857  Maybe     No  I don't know   No   1      I don't know
# 858     No     No           Yes   No   1          Some did
# 859  Maybe  Maybe  I don't know  Yes   1          Some did
# 860  Maybe     No            No   No   1       No none did
#
#                                  10            11            12  \
# 0               I was aware of some      None did    Yes always
# 1         N/A (not currently aware)      Some did  I don't know
# 2    Yes I was aware of all of them      None did  I don't know
# 3               I was aware of some      None did  I don't know
# 4               I was aware of some      Some did     Sometimes
# ..                              ...           ...           ...
# 856    No I only became aware later      Some did    Yes always
# 857       N/A (not currently aware)  I don't know  I don't know
# 858             I was aware of some      None did  I don't know
# 859             I was aware of some      None did     Sometimes
# 860       N/A (not currently aware)      None did  I don't know
#
#                   13                                   14        15  \
# 0       None of them        Some of my previous employers  Some did
# 1       Some of them        Some of my previous employers  Some did
# 2    Yes all of them  No at none of my previous employers  None did
# 3       None of them  Yes at all of my previous employers  Some did
# 4       Some of them        Some of my previous employers  Some did
# ..               ...                                  ...       ...
# 856     Some of them  No at none of my previous employers  Some did
# 857     Some of them        Some of my previous employers  Some did
# 858     Some of them  No at none of my previous employers  None did
# 859  Yes all of them        Some of my previous employers  None did
# 860  Yes all of them  No at none of my previous employers  None did
#
#                   16     17                         18  \
# 0       None of them     No  No I don't think it would
# 1       Some of them     No       Yes I think it would
# 2       Some of them  Maybe       Yes I think it would
# 3       None of them    Yes       Yes I think it would
# 4       Some of them     No                      Maybe
# ..               ...    ...                        ...
# 856     None of them     No       Yes I think it would
# 857     None of them  Maybe                 Yes it has
# 858  Yes all of them     No                      Maybe
# 859     Some of them     No                 Yes it has
# 860     None of them     No  No I don't think it would
#
#                               19  \
# 0    No I don't think they would
# 1                          Maybe
# 2                          Maybe
# 3    No I don't think they would
# 4                          Maybe
# ..                           ...
# 856                        Maybe
# 857                        Maybe
# 858  No I don't think they would
# 859  No I don't think they would
# 860  No I don't think they would
#
#                                                     20                 21  \
# 0                                        Somewhat open                 No
# 1                                        Somewhat open  Yes I experienced
# 2                                        Somewhat open  Yes I experienced
# 3    Not applicable to me (I do not have a mental i...                 No
# 4                                        Somewhat open     Yes I observed
# ..                                                 ...                ...
# 856                                  Somewhat not open                 No
# 857                                      Somewhat open  Yes I experienced
# 858                                          Very open  Yes I experienced
# 859                                      Somewhat open     Yes I observed
# 860                                      Somewhat open  Yes I experienced
#
#                22     23     24   25  26                    27  \
# 0             Yes    Yes    Yes  Yes   1                Rarely
# 1             Yes    Yes    Yes  Yes   1             Sometimes
# 2              No     No    Yes   No   1  Not applicable to me
# 3              No     No     No   No   0  Not applicable to me
# 4             Yes    Yes    Yes  Yes   1             Sometimes
# ..            ...    ...    ...  ...  ..                   ...
# 856  I don't know  Maybe  Maybe   No   0                Rarely
# 857  I don't know    Yes    Yes  Yes   1                Rarely
# 858           Yes    Yes    Yes  Yes   1                Rarely
# 859           Yes    Yes  Maybe  Yes   1                Rarely
# 860           Yes  Maybe    Yes  Yes   0             Sometimes
#
#                        28      29                        30  \
# 0               Sometimes    Male  United States of America
# 1               Sometimes  Female  United States of America
# 2                   Often    Male            United Kingdom
# 3    Not applicable to me    Male  United States of America
# 4                   Often  Female  United States of America
# ..                    ...     ...                       ...
# 856                Rarely    Male                    Canada
# 857                 Often  Female                    Canada
# 858                 Often  Female  United States of America
# 859             Sometimes    Male  United States of America
# 860                 Often  Female  United States of America
#
#                            31
# 0    United States of America
# 1    United States of America
# 2              United Kingdom
# 3    United States of America
# 4    United States of America
# ..                        ...
# 856                    Canada
# 857                    Canada
# 858  United States of America
# 859  United States of America
# 860  United States of America
#
# [861 rows x 32 columns]

# %% [markdown]
# # Create Database

# %%
# Create an in-memory SQLite database

# Create the engine
engine = create_engine("sqlite:///mental_health.db", echo=False)

# Reflect existing db into a new model
Base = automap_base()
# Refelct the tables
Base.prepare(engine, reflect=True)

# %%
# Use pandas to_sql to write records stored in a dataframe to a SQL database

# Write dataframe of all survey questions to a sqlite table
renamed_df.to_sql('pre_encoded', con=engine, if_exists='replace')
# Write dataframe of all questions with encoded numbers to a sqlite table
questions_df.to_sql('pre_encoded_questions', con=engine, if_exists='replace')

# %%
# Check that you can select a table from the database
#engine.execute("SELECT * FROM pre_encoded").fetchall()
engine.execute("SELECT * FROM pre_encoded_questions").fetchall()
# Out:
# [(0, 'Does your employer provide mental health benefits as part of healthcare coverage?'),
#  (1, 'Do you know the options for mental health care available under your employer-provided coverage?'),
#  (2, 'Does your employer offer resources to learn more about mental health concerns and options for seeking help?'),
#  (3, 'If a mental health issue prompted you to request a medical leave from work asking for that leave would be:'),
#  (4, 'Do you think that discussing a mental health disorder with your employer would have negative consequences?'),
#  (5, 'Do you think that discussing a physical health issue with your employer would have negative consequences?'),
#  (6, 'Do you feel that your employer takes mental health as seriously as physical health?'),
#  (7, 'Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?'),
#  (8, 'Do you have previous employers?'),
#  (9, 'Have your previous employers provided mental health benefits?'),
#  (10, 'Were you aware of the options for mental health care provided by your previous employers?'),
#  (11, 'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?'),
#  (12, 'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?'),
#  (13, 'Do you think that discussing a mental health disorder with previous employers would have negative consequences?'),
#  (14, 'Would you have been willing to discuss a mental health issue with your direct supervisor(s)?'),
#  (15, 'Did you feel that your previous employers took mental health as seriously as physical health?'),
#  (16, 'Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?'),
#  (17, 'Would you bring up a mental health issue with a potential employer in an interview?'),
#  (18, 'Do you feel that being identified as a person with a mental health issue would hurt your career?'),
#  (19, 'Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?'),
#  (20, 'How willing would you be to share with friends and family that you have a mental illness?'),
#  (21, 'Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?'),
#  (22, 'Do you have a family history of mental illness?'),
#  (23, 'Have you had a mental health disorder in the past?'),
#  (24, 'Do you currently have a mental health disorder?'),
#  (25, 'Have you been diagnosed with a mental health condition by a medical professional?'),
#  (26, 'Have you ever sought treatment for a mental health issue from a mental health professional?'),
#  (27, 'If you have a mental health issue do you feel that it interferes with your work when being treated effectively?'),
#  (28, 'If you have a mental health issue do you feel that it interferes with your work when NOT being treated effectively?'),
#  (29, 'What is your gender?'),
#  (30, 'What country do you live in?'),
#  (31, 'What country do you work in?')]
